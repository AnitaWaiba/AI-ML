# %% [markdown]
# Read the image using the Pillow library and display it.

# %%
from PIL import Image
# display image in colab
image_colored = Image . open ("/content/drive/MyDrive/AL and ML/Lenna_(test_image).png")
display ( image_colored )
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %% [markdown]
# Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
# Array Indexing.

# %%
from PIL import Image
import numpy as np

image_colored = Image.open("/content/drive/MyDrive/AL and ML/Lenna_(test_image).png")

image_np = np.array(image_colored)

top_left_corner = image_np[:100, :100]

corner_image = Image.fromarray(top_left_corner)

display(corner_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# Separate the image into its three color channels (Red, Green, and Blue) and display them
# individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
import numpy as np
from PIL import Image

image_colored = Image.open("/content/drive/MyDrive/AL and ML/Lenna_(test_image).png")

image_np = np.array(image_colored)

r = image_np[:, :, 0]
g = image_np[:, :, 1]
b = image_np[:, :, 2]

display(Image.fromarray(r))
display(Image.fromarray(g))
display(Image.fromarray(b))
# Out:
# <PIL.Image.Image image mode=L size=512x512>
# <PIL.Image.Image image mode=L size=512x512>
# <PIL.Image.Image image mode=L size=512x512>

# %% [markdown]
# Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
# • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a
# light gray color), and then display the modified image.

# %%
import numpy as np
from PIL import Image

image_colored = Image.open("/content/drive/MyDrive/AL and ML/Lenna_(test_image).png")
image_np = np.array(image_colored)

image_np[:100, :100] = 210

modified_image = Image.fromarray(image_np)
display(modified_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# **Exercise 2**

# %% [markdown]
# 1. Load and display a grayscale image.
# • Load a grayscale image using the Pillow library.
# • Display the grayscale image using matplotlib.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load the grayscale image
image = Image.open("/content/drive/MyDrive/AL and ML/cameraman.png")

# Display the image using matplotlib
plt.imshow(image, cmap="gray")
plt.axis('off')
plt.show()

# %% [markdown]
# 2. Extract and display the middle section of the image (150 pixels).
# • Extract a 150 pixel section from the center of the image using NumPy array slicing.
# • Display this cropped image using matplotlib.

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("/content/drive/MyDrive/AL and ML/cameraman.png").convert("L")
image_np = np.array(image)

height, width = image_np.shape

center_x = width // 2
center_y = height // 2
start_x = center_x - 75
end_x = center_x + 75
start_y = center_y - 75
end_y = center_y + 75

middle_section = image_np[start_y:end_y, start_x:end_x]

plt.imshow(middle_section, cmap="gray")
plt.title("Middle Section (150x150)")
plt.axis('off')
plt.show()

# %% [markdown]
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
# • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
# above 100 to 255 (creating a binary image).
# • Display the resulting binary image.

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("/content/drive/MyDrive/AL and ML/cameraman.png").convert('L')
image_np = np.array(image)

threshold_value = 100
binary_image = np.where(image_np > threshold_value, 255, 0)

plt.imshow(binary_image, cmap="gray")
plt.title("Binary Image (Threshold = 100)")
plt.axis('off')
plt.show()

# %% [markdown]
# 4. Rotate the image 90 degrees clockwise and display the result.
# • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating
# the image array.
# • Display the rotated image using matplotlib.

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("/content/drive/MyDrive/AL and ML/cameraman.png").convert('L')
rotated_image = image.rotate(-90)

plt.imshow(rotated_image, cmap="gray")
plt.title("Rotated Image (90 degrees clockwise)")
plt.axis('off')
plt.show()

# %% [markdown]
# 5. Convert the grayscale image to an RGB image.
# • Convert the grayscale image into an RGB image where the grayscale values are replicated
# across all three channels (R, G, and B).
# • Display the converted RGB image using matplotlib.

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("/content/drive/MyDrive/AL and ML/cameraman.png").convert('L')

rgb_image = image.convert('RGB')

plt.imshow(rgb_image)
plt.title("Converted RGB Image")
plt.axis('off')
plt.show()

# %% [markdown]
# **Exercise 3**

# %% [markdown]
# 1. Load and Prepare Data:
# • Fetch an image of you choice.{If colour convert to grayscale}
# • Center the dataset - Standaridze the Data.
# • Calculate the covaraince matrix of the Standaridze data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

image_path = "//content/drive/MyDrive/AL and ML/Lenna_(test_image).png"
image = Image.open(image_path).convert("L")

image_array = np.array(image, dtype=np.float64)

mean_value = np.mean(image_array)
std_value = np.std(image_array)
standardized_image = (image_array - mean_value) / std_value

covariance_matrix = np.cov(standardized_image, rowvar=False)

plt.imshow(image_array, cmap="gray")
plt.title("Grayscale Lena Image")
plt.axis("off")
plt.show()

print("Covariance Matrix Shape:", covariance_matrix.shape)
print("Covariance Matrix:\n", covariance_matrix)
# Out:
# Covariance Matrix Shape: (512, 512)
# Covariance Matrix:
#  [[ 0.67592652  0.67592652  0.65760065 ... -0.20345282 -0.19127163
#   -0.17274404]
#  [ 0.67592652  0.67592652  0.65760065 ... -0.20345282 -0.19127163
#   -0.17274404]
#  [ 0.65760065  0.65760065  0.65000039 ... -0.22661402 -0.2152941
#   -0.19732349]
#  ...
#  [-0.20345282 -0.20345282 -0.22661402 ...  1.34629876  1.33745396
#    1.32274375]
#  [-0.19127163 -0.19127163 -0.2152941  ...  1.33745396  1.34136651
#    1.33306917]
#  [-0.17274404 -0.17274404 -0.19732349 ...  1.32274375  1.33306917
#    1.33995127]]

# %% [markdown]
# 2. Eigen Decomposition and Identifying Principal Components:
# • Compute Eigen Values and Eigen Vectors.
# • Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to
# the highest eigenvalues.
# • Identify the Principal Components with the help of cumulative Sum plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

image_path = "/content/drive/MyDrive/AL and ML/Lenna_(test_image).png"
image = Image.open(image_path).convert("L")

image_array = np.array(image, dtype=np.float64)

mean_value = np.mean(image_array)
std_value = np.std(image_array)
standardized_image = (image_array - mean_value) / std_value

covariance_matrix = np.cov(standardized_image, rowvar=False)

eigenvalues, eigenvectors = np.linalg.eig(covariance_matrix)

sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

cumulative_sum = np.cumsum(eigenvalues) / np.sum(eigenvalues)

plt.plot(cumulative_sum, marker='o', linestyle='--', color='b')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Cumulative Sum of Eigenvalues")
plt.grid()
plt.show()

# %% [markdown]
# 3. Reconstruction and Experiment:
#
# • Reconstruction: Transform the original data by multiplying it with the selected eigenvec-
# tors(PCs) to obtain a lower-dimensional representation.
#
# • Experiments: Pick Four different combination of principal components with various ex-
# plained variance value and compare the result.
#
# • Display the Results and Evaluate.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

image_path = "/content/drive/MyDrive/AL and ML/Lenna_(test_image).png"
image = Image.open(image_path).convert("L")

image_array = np.array(image, dtype=np.float64)

mean_value = np.mean(image_array, axis=0)
std_value = np.std(image_array, axis=0)
standardized_image = (image_array - mean_value) / std_value

U, S, Vt = np.linalg.svd(standardized_image, full_matrices=False)

def reconstruct_image(k):
    projected_data = np.dot(U[:, :k], np.diag(S[:k]))
    reconstructed_image = np.dot(projected_data, Vt[:k, :])
    reconstructed_image = (reconstructed_image * std_value) + mean_value
    return np.clip(reconstructed_image, 0, 255)

k_values = [10, 20, 50, 100]
fig, axes = plt.subplots(1, 5, figsize=(15, 5))

axes[0].imshow(image_array, cmap="gray")
axes[0].set_title("Original Image")
axes[0].axis("off")

for i, k in enumerate(k_values):
    reconstructed = reconstruct_image(k)
    axes[i + 1].imshow(reconstructed, cmap="gray")
    axes[i + 1].set_title(f"{k} PCs")
    axes[i + 1].axis("off")

plt.show()
